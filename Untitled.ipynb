# %%
from scipy import misc
image = misc.imread('frame0000.jpg')

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
plt.imshow(image, interpolation='nearest')
plt.show()

# %%
a = image[479-210:, :,:]

plt.imshow(image[479-210:, :,:], interpolation='nearest')
plt.show()

plt.imshow(misc.imresize(a, (66, 200, 3)))
plt.show()
